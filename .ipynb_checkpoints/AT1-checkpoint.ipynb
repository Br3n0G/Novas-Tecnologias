# %% [markdown]
# # Exercício 1 - Cadastro e análise simples de veículos
#
# Uma concessionária deseja registrar alguns veículos disponíveis para venda.
# Crie um programa em Python que crie uma lista de veículos.
#
# Cada veículo deve ser representado por um dicionário contendo:
# - marca
# - modelo
# - preço
# - ano
#
# Exemplo de estrutura esperada:
#
# ```
# veiculo = {
#     "marca": "Toyota",
#     "modelo": "Corolla",
#     "preco": 120000,
#     "ano": 2022
# }
# ```
#
# O programa deve:
#
# - Adicionar pelo *menos 5 veículos* à lista.
# - Exibir todos os veículos cadastrados.
# - Calcular o *preço médio dos veículos*.
# - Mostrar quais *veículos custam acima da média*.
#
# ### Saída esperada (exemplo)
# ```
# Preço médio dos veículos: 85000
# Veículos acima da média:
# Honda Civic - 110000
# Toyota Corolla - 120000
# ```

# %%
# Solução do exercício 1
veiculos = [
    {"marca": "Porsche", "modelo": "911 Carrera", "preco": 835000, "ano": 2023},
    {"marca": "BMW", "modelo": "M4 Competition", "preco": 720000, "ano": 2023},
    {"marca": "Mercedes-Benz", "modelo": "G 63 AMG", "preco": 1850000, "ano": 2022},
    {"marca": "Audi", "modelo": "RS6 Avant", "preco": 1160000, "ano": 2023},
    {"marca": "Lamborghini", "modelo": "Urus", "preco": 3900000, "ano": 2023}
]

print("Veículos de luxo cadastrados:")
for v in veiculos:
    print(f"- {v['marca']} {v['modelo']} ({v['ano']}): R$ {v['preco']:,.2f}")

precos = [v['preco'] for v in veiculos]
preco_medio = sum(precos) / len(precos)
print(f"\nPreço médio dos veículos: R$ {preco_medio:,.2f}")

print("Veículos acima da média:")
for v in veiculos:
    if v['preco'] > preco_medio:
        print(f"{v['marca']} {v['modelo']} - R$ {v['preco']:,.2f}")
# Out:
# Veículos de luxo cadastrados:
# - Porsche 911 Carrera (2023): R$ 835,000.00
# - BMW M4 Competition (2023): R$ 720,000.00
# - Mercedes-Benz G 63 AMG (2022): R$ 1,850,000.00
# - Audi RS6 Avant (2023): R$ 1,160,000.00
# - Lamborghini Urus (2023): R$ 3,900,000.00
#
# Preço médio dos veículos: R$ 1,693,000.00
# Veículos acima da média:
# Mercedes-Benz G 63 AMG - R$ 1,850,000.00
# Lamborghini Urus - R$ 3,900,000.00

# %% [markdown]
# # Exercício 2 - Sistema simples de financiamento
#
# Uma concessionária oferece financiamento de veículos.
#
# Crie uma função chamada:
#
# ```
# calcular_financiamento(preco, entrada, parcelas)
# ```
#
# A função deve calcular o valor financiado.
#
# ```
# valor_financiado = preco - entrada
# ```
#
# Considerar uma taxa de juros simples de 1.5% ao mês.
#
# Fórmula simplificada:
# ```
# valor_total = valor_financiado * (1 + taxa * parcelas)
# parcela = valor_total / parcelas
# ```
# A função deve retornar o valor da parcela.
#
#
# ### Crie um programa que:
#
# - Defina o preço de um veículo
# - Pergunte ao usuário: valor de entrada e número de parcelas
# - Use a função para calcular o financiamento
# - Exiba o valor da parcela
# - Impedir parcelas maiores que 72 meses
# - Mostrar uma mensagem caso isso ocorra (Número máximo de parcelas é 72.)
#
# ### Exemplo de saída
#
# ```
# Preço do veículo: 80000
# Entrada: 20000
# Parcelas: 48
# Valor da parcela: 1785.50
# ```

# %%
# Solução do exercício 2
def calcular_financiamento(preco, entrada, parcelas):
    if parcelas > 72:
        return "Número máximo de parcelas é 72."
    
    taxa = 0.015  # 1.5% ao mês
    valor_financiado = preco - entrada
    
    valor_total = valor_financiado * (1 + taxa * parcelas)
    valor_parcela = valor_total / parcelas
    
    return valor_parcela

# Programa principal
preco_veiculo = 160000
print(f"Preço do veículo: {preco_veiculo}")

try:
    entrada_usuario = float(input("Valor de entrada: "))
    n_parcelas = int(input("Número de parcelas: "))

    resultado = calcular_financiamento(preco_veiculo, entrada_usuario, n_parcelas)

    if isinstance(resultado, str):
        print(resultado)
    else:
        print(f"Valor da parcela: R$ {resultado:,.2f}")
except ValueError:
    print("Erro: Insira apenas valores numéricos.")
# Out:
# Preço do veículo: 160000
# Valor de entrada:  3000
# Número de parcelas:  7
# Valor da parcela: R$ 24,783.57
